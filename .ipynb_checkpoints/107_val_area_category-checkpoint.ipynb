# %%
import numpy as np
import pandas as pd
from sklearn import neighbors
from sklearn.cluster import KMeans

# %%
# %%time
train_df = pd.read_csv("./input/train.csv")
test_df = pd.read_csv("./input/test.csv")
# Out:
# Wall time: 47.6 s

# %%
submit_flg=1 #全件処理かどうかをコントロール
grid_flg=1 #GridSearchをするかコントロール
SEED=12345
sample_num=10000
fold_num=5

#train関連
train_drop_col=['ID_code', 'target']
train_label='target'

#test関連
test_drop_col=['ID_code']

# %%
#x,y作成
x_train=train_df.drop(train_drop_col,axis=1)
y_train=train_df[train_label]
x_test=test_df.drop(test_drop_col,axis=1)

# %% [markdown]
# 特徴量作成コードを記載

# %%
train_df.head()
# Out:
#    ID_code  target    var_0   var_1    var_2   var_3    var_4   var_5   var_6  \
# 0  train_0       0   8.9255 -6.7863  11.9081  5.0930  11.4607 -9.2834  5.1187
# 1  train_1       0  11.5006 -4.1473  13.8588  5.3890  12.3622  7.0433  5.6208
# 2  train_2       0   8.6093 -2.7457  12.0805  7.8928  10.5825 -9.0837  6.9427
# 3  train_3       0  11.0604 -2.1518   8.9522  7.1957  12.5846 -1.8361  5.8428
# 4  train_4       0   9.8369 -1.4834  12.8746  6.6375  12.2772  2.4486  5.9405
#
#      var_7   ...     var_190  var_191  var_192  var_193  var_194  var_195  \
# 0  18.6266   ...      4.4354   3.9642   3.1364   1.6910  18.5227  -2.3978
# 1  16.5338   ...      7.6421   7.7214   2.5837  10.9516  15.4305   2.0339
# 2  14.6155   ...      2.9057   9.7905   1.6704   1.6858  21.6042   3.1417
# 3  14.9250   ...      4.4666   4.7433   0.7178   1.4214  23.0347  -1.2706
# 4  19.2514   ...     -1.4905   9.5214  -0.1508   9.1942  13.2876  -1.5121
#
#    var_196  var_197  var_198  var_199
# ...

# %%
for i in train_df.columns:
    series_temp=train_df[i].value_counts()
    print("{} unique count:{}".format(i,series_temp.count()))
# Out:
# ID_code unique count:200000
# target unique count:2
# var_0 unique count:94672
# var_1 unique count:108932
# var_2 unique count:86555
# var_3 unique count:74597
# var_4 unique count:63515
# var_5 unique count:141029
# var_6 unique count:38599
# var_7 unique count:103063
# var_8 unique count:98617
# var_9 unique count:49417
# var_10 unique count:128764
# var_11 unique count:130193
# var_12 unique count:9561
# var_13 unique count:115181
# var_14 unique count:79122
# var_15 unique count:19810
# var_16 unique count:86918
# var_17 unique count:137823
# var_18 unique count:139515
# var_19 unique count:144180
# var_20 unique count:127764
# var_21 unique count:140062
# var_22 unique count:90660
# var_23 unique count:24913
# var_24 unique count:105101
# var_25 unique count:14853
# var_26 unique count:127089
# var_27 unique count:60185
# var_28 unique count:35859
# var_29 unique count:88339
# var_30 unique count:145977
# var_31 unique count:77388
# var_32 unique count:85964
# ...

# %% [markdown]
# var_68だけが451パターンしかない

# %%
var_68=train_df['var_68'].value_counts()

# %%
df_var_68=var_68.to_frame()
df_var_68
# Out:
#         var_68
# 5.0214    1084
# 5.0215    1081
# 5.0209    1080
# 5.0183    1077
# 5.0179    1071
# 5.0208    1070
# 5.0193    1070
# 5.0202    1069
# 5.0174    1066
# 5.0203    1063
# 5.0189    1063
# 5.0195    1062
# 5.0220    1060
# 5.0204    1059
# 5.0211    1058
# 5.0188    1057
# 5.0157    1054
# 5.0158    1049
# 5.0219    1049
# 5.0190    1048
# 5.0201    1047
# 5.0221    1043
# 5.0207    1040
# 5.0192    1038
# 5.0212    1038
# 5.0184    1035
# 5.0205    1033
# 5.0151    1031
# 5.0185    1029
# 5.0197    1029
# 5.0227    1028
# 5.0145    1028
# 5.0226    1028
# 5.0199    1027
# 5.0216    1027
# 5.0194    1022
# 5.0181    1022
# 5.0177    1022
# 5.0210    1021
# 5.0152    1011
# 5.0176    1011
# 5.0162    1008
# 5.0236    1007
# 5.0187    1006
# 5.0228    1006
# 5.0175    1005
# 5.0198    1005
# 5.0159    1001
# 5.0196     999
# 5.0191     999
# 5.0232     997
# 5.0229     997
# 5.0200     996
# 5.0170     995
# 5.0186     993
# 5.0168     993
# 5.0218     993
# ...

# %%
pd.set_option('display.max_rows', 500)
df_var_68=df_var_68.sort_index(ascending=True)
df_var_68.head(451)
# Out:
#         var_68
# 4.9938       1
# 4.9951       1
# 4.9964       1
# 4.9967       1
# 4.9976       1
# 4.9977       1
# 4.9978       1
# 4.9979       1
# 4.9980       2
# 4.9983       1
# 4.9984       1
# 4.9985       3
# 4.9988       2
# 4.9989       1
# 4.9990       1
# 4.9992       2
# 4.9993       1
# 4.9995       1
# 4.9996       3
# 4.9997       2
# 4.9998       3
# 4.9999       1
# 5.0000       1
# 5.0001      12
# 5.0002      12
# 5.0003      14
# 5.0004      24
# 5.0005      36
# 5.0006      57
# 5.0007      68
# 5.0008      84
# 5.0009     130
# 5.0010     132
# 5.0011     175
# 5.0012     162
# 5.0013     201
# 5.0014     186
# 5.0015     219
# 5.0016     245
# 5.0017     240
# 5.0018     225
# 5.0019     212
# 5.0020     181
# 5.0021     217
# 5.0022     175
# 5.0023     165
# 5.0024     182
# 5.0025     157
# 5.0026     134
# 5.0027     143
# 5.0028     147
# 5.0029     147
# 5.0030     162
# 5.0031     168
# 5.0032     146
# 5.0033     144
# 5.0034     153
# ...

# %%
pd.set_option('display.max_rows', 1000)
train_df[['var_68', 'target']].groupby(['var_68', 'target']).size().to_frame()
# Out:
#                  0
# var_68 target
# 4.9938 0         1
# 4.9951 0         1
# 4.9964 0         1
# 4.9967 0         1
# 4.9976 0         1
# 4.9977 0         1
# 4.9978 0         1
# 4.9979 0         1
# 4.9980 0         2
# 4.9983 0         1
# 4.9984 0         1
# 4.9985 0         3
# 4.9988 0         2
# 4.9989 0         1
# 4.9990 0         1
# 4.9992 0         2
# 4.9993 0         1
# 4.9995 0         1
# 4.9996 0         2
#        1         1
# 4.9997 0         2
# 4.9998 0         3
# 4.9999 1         1
# 5.0000 0         1
# 5.0001 0        10
#        1         2
# 5.0002 0         9
#        1         3
# 5.0003 0        11
#        1         3
# 5.0004 0        18
#        1         6
# 5.0005 0        31
#        1         5
# 5.0006 0        52
#        1         5
# 5.0007 0        61
#        1         7
# 5.0008 0        69
#        1        15
# 5.0009 0       113
#        1        17
# 5.0010 0       113
#        1        19
# 5.0011 0       163
# ...

# %%
# Out:
#         var_68
# 4.9938       1
# 4.9951       1
# 4.9964       1
# 4.9967       1
# 4.9976       1

# %%
for i in df_var_68.index:
    num=i
    count_val=df_var_68['var_68'].loc[i]
# Out:
# 4.9938
# 1
# 4.9951
# 1
# 4.9964
# 1
# 4.9967
# 1
# 4.9976
# 1
# 4.9977
# 1
# 4.9978
# 1
# 4.9979
# 1
# 4.998
# 2
# 4.9983
# 1
# 4.9984
# 1
# 4.9985
# 3
# 4.9988
# 2
# 4.9989
# 1
# 4.999
# 1
# 4.9992
# 2
# 4.9993
# 1
# 4.9995
# 1
# 4.9996
# 3
# 4.9997
# 2
# 4.9998
# 3
# 4.9999
# 1
# 5.0
# 1
# 5.0001
# 12
# 5.0002
# 12
# 5.0003
# 14
# 5.0004
# 24
# 5.0005
# 36
# 5.0006
# 57
# 5.0007
# 68
# 5.0008
# 84
# 5.0009
# 130
# 5.001
# 132
# 5.0011
# 175
# 5.0012
# 162
# 5.0013
# 201
# 5.0014
# 186
# 5.0015
# 219
# 5.0016
# 245
# 5.0017
# 240
# 5.0018
# 225
# 5.0019
# 212
# 5.002
# 181
# 5.0021
# 217
# 5.0022
# 175
# 5.0023
# 165
# 5.0024
# 182
# 5.0025
# 157
# 5.0026
# 134
# 5.0027
# 143
# 5.0028
# 147
# 5.0029
# 147
# 5.003
# 162
# 5.0031
# 168
# 5.0032
# 146
# 5.0033
# 144
# 5.0034
# 153
# 5.0035
# 131
# 5.0036
# 172
# 5.0037
# 156
# 5.0038
# 142
# 5.0039
# 144
# 5.004
# 137
# 5.0041
# 151
# 5.0042
# 177
# 5.0043
# 157
# 5.0044
# 155
# 5.0045
# 154
# 5.0046
# 182
# 5.0047
# 161
# 5.0048
# ...

# %%
train_df_iforest.to_csv('./feature/105_train_iforest.csv',index=False)
