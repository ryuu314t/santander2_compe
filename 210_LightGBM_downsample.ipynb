# %%
import gc
import os
import logging
import datetime
import warnings
import numpy as np
import pandas as pd
import seaborn as sns
import lightgbm as lgb
from tqdm import tqdm_notebook
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error
from sklearn.metrics import roc_auc_score, roc_curve
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import ShuffleSplit
import xgboost as xgb
from sklearn.model_selection import GridSearchCV
from sklearn.grid_search import RandomizedSearchCV
warnings.filterwarnings('ignore')
# Out:
# C:\Users\tatsuya.okamoto\AppData\Local\Continuum\Anaconda3\lib\site-packages\sklearn\cross_validation.py:44: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)
# C:\Users\tatsuya.okamoto\AppData\Local\Continuum\Anaconda3\lib\site-packages\sklearn\grid_search.py:43: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. This module will be removed in 0.20.
#   DeprecationWarning)

# %% [markdown]
# 基本変数定義

# %%
submit_flg=1 #全件処理かどうかをコントロール
grid_flg=0 #GridSearchをするかコントロール

SEED=12345
sample_num=10000
fold_num=5

#train関連
train_dir='./feature/101_train.csv'
train_drop_col=['ID_code', 'target']
train_label='target'

#test関連
test_dir='./feature/101_test.csv'
test_drop_col=['ID_code']

#結果ファイル関連
oof_preds_dir='./oof/110_LightGBM_downsample_preds.csv'
test_preds_dir='./oof/110_LightGBM_downsample_tests.csv'
submission_dir='./submission/110_LightGBM_downsample_submission.csv'
save_col_name='oof_xgb'

sample_submission_dir='./submission/sample_submission.csv'
submission_target_col_name='target'
submission_id_col_name='ID_code'

# %% [markdown]
# テンプレ処理

# %%
#ロード
train_df=pd.read_csv(train_dir)
test_df=pd.read_csv(test_dir)

# %%
#サンプリング
if not(submit_flg ==1):
    train_df=train_df.sample(n=sample_num,random_state=SEED)
    test_df=test_df.sample(n=sample_num,random_state=SEED)

# %%
#x,y作成
x_train=train_df.drop(train_drop_col,axis=1)
y_train=train_df[train_label]
x_test=test_df.drop(test_drop_col,axis=1)

# %%
def LGBM(x_train,y_train,x_test,seed):
    #model_param
    param = {
            'num_leaves': 6,
            'max_bin': 63,
            'min_data_in_leaf': 45,
            'learning_rate': 0.01,
            'min_sum_hessian_in_leaf': 0.000446,
            'bagging_fraction': 0.55, 
            'bagging_freq': 5, 
            'max_depth': 14,
            'save_binary': True,
            'seed': seed,
            'feature_fraction_seed': seed,
            'feature_fraction': 0.51,
            'bagging_seed': seed,
            'drop_seed': seed,
            'data_random_seed': seed,
            'objective': 'binary',
            'boosting_type': 'gbdt',
            'verbose': 1,
            'metric': 'auc',
            'is_unbalance': True,
            'boost_from_average': False,
        }
    folds = StratifiedKFold(n_splits=fold_num, shuffle=True, random_state=seed)
    oof_preds = np.zeros((len(x_train), 1))
    test_preds = np.zeros((len(x_test), 1))
    for fold_, (trn_idx, val_idx) in enumerate(folds.split(x_train.values, y_train.values)):
        print("\n")
        print("Fold {}".format(fold_))
        trn_x,trn_y = x_train.iloc[trn_idx], y_train.iloc[trn_idx]
        val_x,val_y = x_train.iloc[val_idx], y_train.iloc[val_idx]
        trn_data = lgb.Dataset(trn_x,trn_y)
        val_data = lgb.Dataset(val_x,val_y)

        num_round = 15000
        clf = lgb.train(param, trn_data, num_round, valid_sets = [trn_data, val_data], verbose_eval=1000, early_stopping_rounds = 250)
        val_pred = clf.predict(val_x, num_iteration=clf.best_iteration)
        test_pred = clf.predict(x_test, num_iteration=clf.best_iteration)

        print("AUC = {}".format(roc_auc_score(val_y, val_pred)))
        #print("val = {}".format(val_pred)
        oof_preds[val_idx, :] = val_pred.reshape((-1, 1))
        test_preds += test_pred.reshape((-1, 1))

    test_preds /= fold_num
    roc_score = roc_auc_score(y_train, oof_preds.ravel())
    print("Overall AUC = {}".format(roc_score))
    
    return oof_preds,test_preds

# %%
def downsampling(train_df,SEED):
    train_df_0=train_df[train_df['target']==0]
    train_df_1=train_df[train_df['target']==1]
    len_1=len(train_df_1)
    train_df_0=train_df_0.sample(n=len_1,random_state=SEED)
    new_train_df=pd.concat([train_df_0,train_df_1])
    return new_train_df

# %%
new_train_df=downsampling(train_df,100)
all_oof_preds = np.zeros((len(new_train_df), 1))
all_test_preds = np.zeros((len(x_test), 1))
count=0
for i in range(0,9):
    print("\n")
    print(count)
    new_train_df=downsampling(train_df,i)
    x_train=new_train_df.drop(train_drop_col,axis=1)
    y_train=new_train_df[train_label]

    oof_preds,test_preds=LGBM(x_train,y_train,x_test,i)
    
    roc_score = roc_auc_score(y_train, oof_preds.ravel())
    print("Overall AUC = {}".format(roc_score))
    
    all_oof_preds+= oof_preds
    all_test_preds+= test_preds
    
    count+=1

all_oof_preds/=count
all_test_preds/=count
# Out:
# 0
#
#
# Fold 0
# Training until validation scores don't improve for 250 rounds.
# [1000]	training's auc: 0.871137	valid_1's auc: 0.842834
# [2000]	training's auc: 0.90023	valid_1's auc: 0.868897
# [3000]	training's auc: 0.914534	valid_1's auc: 0.880079
# [4000]	training's auc: 0.923265	valid_1's auc: 0.885849
# [5000]	training's auc: 0.929711	valid_1's auc: 0.88872
# [6000]	training's auc: 0.935189	valid_1's auc: 0.890497
# [7000]	training's auc: 0.940317	valid_1's auc: 0.891486
# [8000]	training's auc: 0.945267	valid_1's auc: 0.891965
# Early stopping, best iteration is:
# [8363]	training's auc: 0.946889	valid_1's auc: 0.892127
# AUC = 0.8921274844682062
#
#
# Fold 1
# Training until validation scores don't improve for 250 rounds.
# [1000]	training's auc: 0.870115	valid_1's auc: 0.846859
# [2000]	training's auc: 0.899745	valid_1's auc: 0.873151
# [3000]	training's auc: 0.913807	valid_1's auc: 0.883015
# [4000]	training's auc: 0.922759	valid_1's auc: 0.888504
# [5000]	training's auc: 0.929407	valid_1's auc: 0.891542
# [6000]	training's auc: 0.93498	valid_1's auc: 0.893424
# [7000]	training's auc: 0.940137	valid_1's auc: 0.894
# [8000]	training's auc: 0.945002	valid_1's auc: 0.894578
# Early stopping, best iteration is:
# [8005]	training's auc: 0.945014	valid_1's auc: 0.894591
# AUC = 0.89459122298953
#
#
# Fold 2
# Training until validation scores don't improve for 250 rounds.
# [1000]	training's auc: 0.870685	valid_1's auc: 0.847716
# [2000]	training's auc: 0.900102	valid_1's auc: 0.872398
# [3000]	training's auc: 0.913777	valid_1's auc: 0.882484
# [4000]	training's auc: 0.922655	valid_1's auc: 0.888136
# [5000]	training's auc: 0.929149	valid_1's auc: 0.891147
# [6000]	training's auc: 0.934706	valid_1's auc: 0.893046
# [7000]	training's auc: 0.939767	valid_1's auc: 0.893859
# [8000]	training's auc: 0.944525	valid_1's auc: 0.894363
# [9000]	training's auc: 0.94919	valid_1's auc: 0.89467
# Early stopping, best iteration is:
# [9430]	training's auc: 0.951121	valid_1's auc: 0.894786
# AUC = 0.8947858963887033
#
#
# Fold 3
# Training until validation scores don't improve for 250 rounds.
# [1000]	training's auc: 0.871327	valid_1's auc: 0.854043
# [2000]	training's auc: 0.899875	valid_1's auc: 0.876605
# [3000]	training's auc: 0.914173	valid_1's auc: 0.886049
# [4000]	training's auc: 0.923022	valid_1's auc: 0.890914
# [5000]	training's auc: 0.929637	valid_1's auc: 0.893608
# [6000]	training's auc: 0.935128	valid_1's auc: 0.894956
# Early stopping, best iteration is:
# [6613]	training's auc: 0.938267	valid_1's auc: 0.895398
# AUC = 0.8953981402471132
#
#
# Fold 4
# Training until validation scores don't improve for 250 rounds.
# [1000]	training's auc: 0.870926	valid_1's auc: 0.848496
# [2000]	training's auc: 0.90055	valid_1's auc: 0.872891
# [3000]	training's auc: 0.914495	valid_1's auc: 0.882725
# [4000]	training's auc: 0.92325	valid_1's auc: 0.888007
# [5000]	training's auc: 0.929646	valid_1's auc: 0.890971
# [6000]	training's auc: 0.935307	valid_1's auc: 0.892335
# Early stopping, best iteration is:
# [6702]	training's auc: 0.93903	valid_1's auc: 0.893176
# AUC = 0.8931757406858352
# Overall AUC = 0.8938328100358794
# Overall AUC = 0.8938328100358794
#
#
# 1
#
#
# Fold 0
# Training until validation scores don't improve for 250 rounds.
# [1000]	training's auc: 0.87279	valid_1's auc: 0.852259
# [2000]	training's auc: 0.901757	valid_1's auc: 0.876846
# [3000]	training's auc: 0.915699	valid_1's auc: 0.887233
# [4000]	training's auc: 0.924355	valid_1's auc: 0.892379
# [5000]	training's auc: 0.930867	valid_1's auc: 0.895317
# [6000]	training's auc: 0.936316	valid_1's auc: 0.896954
# [7000]	training's auc: 0.941386	valid_1's auc: 0.897821
# Early stopping, best iteration is:
# [7544]	training's auc: 0.944044	valid_1's auc: 0.898153
# AUC = 0.8981527684958295
#
#
# Fold 1
# Training until validation scores don't improve for 250 rounds.
# [1000]	training's auc: 0.87395	valid_1's auc: 0.852179
# [2000]	training's auc: 0.90281	valid_1's auc: 0.874696
# [3000]	training's auc: 0.916755	valid_1's auc: 0.884938
# [4000]	training's auc: 0.925299	valid_1's auc: 0.890003
# [5000]	training's auc: 0.93175	valid_1's auc: 0.893077
# [6000]	training's auc: 0.937171	valid_1's auc: 0.894915
# [7000]	training's auc: 0.942064	valid_1's auc: 0.895604
# [8000]	training's auc: 0.946777	valid_1's auc: 0.895965
# Early stopping, best iteration is:
# [8016]	training's auc: 0.946837	valid_1's auc: 0.896005
# AUC = 0.8960052350189351
#
#
# Fold 2
# Training until validation scores don't improve for 250 rounds.
# [1000]	training's auc: 0.873049	valid_1's auc: 0.851112
# [2000]	training's auc: 0.902585	valid_1's auc: 0.875976
# [3000]	training's auc: 0.916244	valid_1's auc: 0.885799
# [4000]	training's auc: 0.924897	valid_1's auc: 0.89112
# [5000]	training's auc: 0.931241	valid_1's auc: 0.893724
# [6000]	training's auc: 0.936486	valid_1's auc: 0.895012
# [7000]	training's auc: 0.941566	valid_1's auc: 0.896012
# [8000]	training's auc: 0.946329	valid_1's auc: 0.896702
# [9000]	training's auc: 0.950927	valid_1's auc: 0.89675
# Early stopping, best iteration is:
# [8770]	training's auc: 0.949942	valid_1's auc: 0.896896
# AUC = 0.8968959926734487
#
#
# Fold 3
# Training until validation scores don't improve for 250 rounds.
# [1000]	training's auc: 0.871769	valid_1's auc: 0.852357
# [2000]	training's auc: 0.901312	valid_1's auc: 0.878158
# [3000]	training's auc: 0.915343	valid_1's auc: 0.888468
# [4000]	training's auc: 0.924027	valid_1's auc: 0.893977
# [5000]	training's auc: 0.930454	valid_1's auc: 0.897108
# [6000]	training's auc: 0.935851	valid_1's auc: 0.898758
# [7000]	training's auc: 0.940885	valid_1's auc: 0.900287
# Early stopping, best iteration is:
# [7612]	training's auc: 0.943862	valid_1's auc: 0.900657
# AUC = 0.9006566903748623
#
#
# Fold 4
# Training until validation scores don't improve for 250 rounds.
# [1000]	training's auc: 0.873605	valid_1's auc: 0.848236
# [2000]	training's auc: 0.902683	valid_1's auc: 0.870491
# [3000]	training's auc: 0.916945	valid_1's auc: 0.881046
# [4000]	training's auc: 0.925727	valid_1's auc: 0.88601
# [5000]	training's auc: 0.932064	valid_1's auc: 0.888846
# [6000]	training's auc: 0.937484	valid_1's auc: 0.890395
# [7000]	training's auc: 0.942288	valid_1's auc: 0.891015
# Early stopping, best iteration is:
# [7722]	training's auc: 0.94567	valid_1's auc: 0.891491
# AUC = 0.8914906619533824
# Overall AUC = 0.8966289036839201
# Overall AUC = 0.8966289036839201
#
#
# 2
#
#
# Fold 0
# Training until validation scores don't improve for 250 rounds.
# [1000]	training's auc: 0.873053	valid_1's auc: 0.841421
# [2000]	training's auc: 0.901885	valid_1's auc: 0.866752
# [3000]	training's auc: 0.915576	valid_1's auc: 0.876936
# [4000]	training's auc: 0.924117	valid_1's auc: 0.882793
# [5000]	training's auc: 0.930552	valid_1's auc: 0.886241
# [6000]	training's auc: 0.935934	valid_1's auc: 0.88844
# Early stopping, best iteration is:
# [6748]	training's auc: 0.939803	valid_1's auc: 0.889155
# AUC = 0.8891552808098809
#
#
# Fold 1
# Training until validation scores don't improve for 250 rounds.
# [1000]	training's auc: 0.872094	valid_1's auc: 0.84943
# [2000]	training's auc: 0.90125	valid_1's auc: 0.873959
# [3000]	training's auc: 0.914921	valid_1's auc: 0.882923
# [4000]	training's auc: 0.923717	valid_1's auc: 0.887866
# [5000]	training's auc: 0.930118	valid_1's auc: 0.890342
# [6000]	training's auc: 0.935474	valid_1's auc: 0.891666
# [7000]	training's auc: 0.940554	valid_1's auc: 0.892402
# Early stopping, best iteration is:
# [7669]	training's auc: 0.943867	valid_1's auc: 0.892677
# AUC = 0.892677223336056
#
#
# Fold 2
# Training until validation scores don't improve for 250 rounds.
# [1000]	training's auc: 0.872717	valid_1's auc: 0.851344
# [2000]	training's auc: 0.900882	valid_1's auc: 0.874022
# [3000]	training's auc: 0.91437	valid_1's auc: 0.88358
# [4000]	training's auc: 0.923074	valid_1's auc: 0.888795
# [5000]	training's auc: 0.929671	valid_1's auc: 0.891417
# [6000]	training's auc: 0.935043	valid_1's auc: 0.892675
# [7000]	training's auc: 0.94014	valid_1's auc: 0.893376
# [8000]	training's auc: 0.944982	valid_1's auc: 0.893928
# Early stopping, best iteration is:
# [8369]	training's auc: 0.946726	valid_1's auc: 0.89402
# AUC = 0.8940200118808941
#
#
# Fold 3
# Training until validation scores don't improve for 250 rounds.
# [1000]	training's auc: 0.87142	valid_1's auc: 0.852713
# [2000]	training's auc: 0.899632	valid_1's auc: 0.877353
# [3000]	training's auc: 0.913637	valid_1's auc: 0.888731
# [4000]	training's auc: 0.92224	valid_1's auc: 0.893574
# [5000]	training's auc: 0.928731	valid_1's auc: 0.896321
# [6000]	training's auc: 0.934322	valid_1's auc: 0.897676
# [7000]	training's auc: 0.939528	valid_1's auc: 0.898477
# Early stopping, best iteration is:
# [6916]	training's auc: 0.939109	valid_1's auc: 0.898505
# AUC = 0.898504930641409
#
#
# Fold 4
# Training until validation scores don't improve for 250 rounds.
# [1000]	training's auc: 0.872286	valid_1's auc: 0.852326
# [2000]	training's auc: 0.900224	valid_1's auc: 0.874955
# [3000]	training's auc: 0.914026	valid_1's auc: 0.885146
# [4000]	training's auc: 0.922808	valid_1's auc: 0.890544
# [5000]	training's auc: 0.929047	valid_1's auc: 0.893329
# [6000]	training's auc: 0.93456	valid_1's auc: 0.894905
# [7000]	training's auc: 0.939604	valid_1's auc: 0.89556
# [8000]	training's auc: 0.944461	valid_1's auc: 0.896141
# Early stopping, best iteration is:
# [7922]	training's auc: 0.944069	valid_1's auc: 0.896164
# AUC = 0.8961643440237621
# Overall AUC = 0.89411215574088
# Overall AUC = 0.89411215574088
#
#
# 3
#
#
# Fold 0
# Training until validation scores don't improve for 250 rounds.
# [1000]	training's auc: 0.873224	valid_1's auc: 0.849067
# [2000]	training's auc: 0.90178	valid_1's auc: 0.874502
# [3000]	training's auc: 0.915502	valid_1's auc: 0.884899
# [4000]	training's auc: 0.923948	valid_1's auc: 0.890187
# [5000]	training's auc: 0.930105	valid_1's auc: 0.893423
# [6000]	training's auc: 0.9355	valid_1's auc: 0.895238
# [7000]	training's auc: 0.940653	valid_1's auc: 0.896202
# Early stopping, best iteration is:
# [7726]	training's auc: 0.94413	valid_1's auc: 0.897031
# AUC = 0.8970308903244969
#
#
# Fold 1
# Training until validation scores don't improve for 250 rounds.
# [1000]	training's auc: 0.873518	valid_1's auc: 0.847827
# [2000]	training's auc: 0.902813	valid_1's auc: 0.871554
# [3000]	training's auc: 0.916248	valid_1's auc: 0.88056
# [4000]	training's auc: 0.924994	valid_1's auc: 0.885167
# [5000]	training's auc: 0.931347	valid_1's auc: 0.887765
# [6000]	training's auc: 0.936726	valid_1's auc: 0.888917
# [7000]	training's auc: 0.941813	valid_1's auc: 0.88949
# [8000]	training's auc: 0.94655	valid_1's auc: 0.889639
# Early stopping, best iteration is:
# [8075]	training's auc: 0.946887	valid_1's auc: 0.889698
# AUC = 0.8896979653968962
#
#
# Fold 2
# Training until validation scores don't improve for 250 rounds.
# [1000]	training's auc: 0.874042	valid_1's auc: 0.849508
# [2000]	training's auc: 0.902656	valid_1's auc: 0.874654
# [3000]	training's auc: 0.915862	valid_1's auc: 0.884373
# [4000]	training's auc: 0.924452	valid_1's auc: 0.890302
# [5000]	training's auc: 0.930581	valid_1's auc: 0.89329
# [6000]	training's auc: 0.936002	valid_1's auc: 0.894684
# [7000]	training's auc: 0.940996	valid_1's auc: 0.895473
# [8000]	training's auc: 0.945878	valid_1's auc: 0.895966
# Early stopping, best iteration is:
# [8520]	training's auc: 0.948295	valid_1's auc: 0.89619
# AUC = 0.8961900695527338
#
#
# Fold 3
# Training until validation scores don't improve for 250 rounds.
# [1000]	training's auc: 0.872622	valid_1's auc: 0.857316
# [2000]	training's auc: 0.901522	valid_1's auc: 0.879931
# [3000]	training's auc: 0.915144	valid_1's auc: 0.889923
# [4000]	training's auc: 0.923538	valid_1's auc: 0.894475
# [5000]	training's auc: 0.929893	valid_1's auc: 0.896692
# [6000]	training's auc: 0.935411	valid_1's auc: 0.898124
# [7000]	training's auc: 0.940401	valid_1's auc: 0.898821
# Early stopping, best iteration is:
# [7491]	training's auc: 0.942837	valid_1's auc: 0.899073
# AUC = 0.899073206697151
#
#
# Fold 4
# Training until validation scores don't improve for 250 rounds.
# [1000]	training's auc: 0.874565	valid_1's auc: 0.855372
# [2000]	training's auc: 0.901947	valid_1's auc: 0.877332
# [3000]	training's auc: 0.915507	valid_1's auc: 0.887086
# [4000]	training's auc: 0.924044	valid_1's auc: 0.892425
# [5000]	training's auc: 0.930319	valid_1's auc: 0.894981
# [6000]	training's auc: 0.935591	valid_1's auc: 0.896638
# [7000]	training's auc: 0.940529	valid_1's auc: 0.897284
# [8000]	training's auc: 0.945402	valid_1's auc: 0.897709
# [9000]	training's auc: 0.950017	valid_1's auc: 0.897974
# Early stopping, best iteration is:
# [9143]	training's auc: 0.950664	valid_1's auc: 0.898092
# AUC = 0.8980917402725211
# Overall AUC = 0.8960141282439897
# Overall AUC = 0.8960141282439897
#
#
# 4
#
#
# Fold 0
# Training until validation scores don't improve for 250 rounds.
# [1000]	training's auc: 0.87267	valid_1's auc: 0.857142
# [2000]	training's auc: 0.902183	valid_1's auc: 0.880824
# [3000]	training's auc: 0.915695	valid_1's auc: 0.890901
# [4000]	training's auc: 0.924242	valid_1's auc: 0.89552
# [5000]	training's auc: 0.930435	valid_1's auc: 0.898212
# [6000]	training's auc: 0.935736	valid_1's auc: 0.900025
# [7000]	training's auc: 0.940661	valid_1's auc: 0.900998
# [8000]	training's auc: 0.945478	valid_1's auc: 0.901477
# Early stopping, best iteration is:
# [8442]	training's auc: 0.947511	valid_1's auc: 0.901637
# AUC = 0.9016372119501992
#
#
# Fold 1
# Training until validation scores don't improve for 250 rounds.
# [1000]	training's auc: 0.874282	valid_1's auc: 0.847337
# [2000]	training's auc: 0.90364	valid_1's auc: 0.871041
# [3000]	training's auc: 0.917683	valid_1's auc: 0.880943
# [4000]	training's auc: 0.926474	valid_1's auc: 0.885586
# [5000]	training's auc: 0.932669	valid_1's auc: 0.888463
# [6000]	training's auc: 0.938054	valid_1's auc: 0.88988
# [7000]	training's auc: 0.942846	valid_1's auc: 0.890438
# Early stopping, best iteration is:
# [7419]	training's auc: 0.944854	valid_1's auc: 0.890615
# AUC = 0.8906148362664291
#
#
# Fold 2
# Training until validation scores don't improve for 250 rounds.
# [1000]	training's auc: 0.871334	valid_1's auc: 0.858044
# [2000]	training's auc: 0.900817	valid_1's auc: 0.881574
# [3000]	training's auc: 0.91495	valid_1's auc: 0.891901
# [4000]	training's auc: 0.923722	valid_1's auc: 0.897168
# [5000]	training's auc: 0.930265	valid_1's auc: 0.899964
# [6000]	training's auc: 0.935748	valid_1's auc: 0.901472
# [7000]	training's auc: 0.940757	valid_1's auc: 0.902277
# [8000]	training's auc: 0.945523	valid_1's auc: 0.902653
# Early stopping, best iteration is:
# [7788]	training's auc: 0.944501	valid_1's auc: 0.902698
# AUC = 0.9026981386599341
#
#
# Fold 3
# Training until validation scores don't improve for 250 rounds.
# [1000]	training's auc: 0.872866	valid_1's auc: 0.849226
# [2000]	training's auc: 0.901993	valid_1's auc: 0.874196
# [3000]	training's auc: 0.915837	valid_1's auc: 0.884765
# [4000]	training's auc: 0.924424	valid_1's auc: 0.890568
# [5000]	training's auc: 0.930943	valid_1's auc: 0.893837
# [6000]	training's auc: 0.936214	valid_1's auc: 0.895699
# [7000]	training's auc: 0.941243	valid_1's auc: 0.896717
# [8000]	training's auc: 0.945875	valid_1's auc: 0.897403
# Early stopping, best iteration is:
# [8021]	training's auc: 0.945979	valid_1's auc: 0.897422
# AUC = 0.8974218072515837
#
#
# Fold 4
# Training until validation scores don't improve for 250 rounds.
# [1000]	training's auc: 0.873884	valid_1's auc: 0.841758
# [2000]	training's auc: 0.904052	valid_1's auc: 0.867853
# [3000]	training's auc: 0.91768	valid_1's auc: 0.878514
# [4000]	training's auc: 0.926418	valid_1's auc: 0.884231
# [5000]	training's auc: 0.932719	valid_1's auc: 0.886993
# [6000]	training's auc: 0.938151	valid_1's auc: 0.888751
# [7000]	training's auc: 0.942988	valid_1's auc: 0.889599
# [8000]	training's auc: 0.947646	valid_1's auc: 0.890126
# Early stopping, best iteration is:
# [8165]	training's auc: 0.94836	valid_1's auc: 0.890223
# AUC = 0.8902233549634013
# Overall AUC = 0.8965027282328135
# Overall AUC = 0.8965027282328135
#
#
# 5
#
#
# Fold 0
# Training until validation scores don't improve for 250 rounds.
# [1000]	training's auc: 0.871589	valid_1's auc: 0.849093
# [2000]	training's auc: 0.900699	valid_1's auc: 0.873777
# [3000]	training's auc: 0.91455	valid_1's auc: 0.883965
# [4000]	training's auc: 0.9232	valid_1's auc: 0.889311
# [5000]	training's auc: 0.929798	valid_1's auc: 0.892537
# [6000]	training's auc: 0.935325	valid_1's auc: 0.893814
# [7000]	training's auc: 0.940247	valid_1's auc: 0.894896
# [8000]	training's auc: 0.945123	valid_1's auc: 0.895438
# Early stopping, best iteration is:
# [8107]	training's auc: 0.945647	valid_1's auc: 0.895462
# AUC = 0.8954623647929506
#
#
# Fold 1
# Training until validation scores don't improve for 250 rounds.
# [1000]	training's auc: 0.87351	valid_1's auc: 0.845884
# [2000]	training's auc: 0.901308	valid_1's auc: 0.869754
# [3000]	training's auc: 0.915287	valid_1's auc: 0.880261
# [4000]	training's auc: 0.9242	valid_1's auc: 0.885746
# [5000]	training's auc: 0.930569	valid_1's auc: 0.888667
# [6000]	training's auc: 0.93591	valid_1's auc: 0.890313
# [7000]	training's auc: 0.940791	valid_1's auc: 0.891526
# [8000]	training's auc: 0.945685	valid_1's auc: 0.892055
# Early stopping, best iteration is:
# [8589]	training's auc: 0.948399	valid_1's auc: 0.892448
# AUC = 0.8924480829682434
#
#
# Fold 2
# Training until validation scores don't improve for 250 rounds.
# [1000]	training's auc: 0.872297	valid_1's auc: 0.84379
# [2000]	training's auc: 0.901106	valid_1's auc: 0.869351
# [3000]	training's auc: 0.91487	valid_1's auc: 0.87938
# [4000]	training's auc: 0.923914	valid_1's auc: 0.885186
# [5000]	training's auc: 0.930357	valid_1's auc: 0.888774
# [6000]	training's auc: 0.935819	valid_1's auc: 0.890536
# [7000]	training's auc: 0.940805	valid_1's auc: 0.891557
# [8000]	training's auc: 0.945451	valid_1's auc: 0.89222
# [9000]	training's auc: 0.949961	valid_1's auc: 0.892505
# Early stopping, best iteration is:
# [9218]	training's auc: 0.950925	valid_1's auc: 0.892584
# AUC = 0.8925837850548253
#
#
# Fold 3
# Training until validation scores don't improve for 250 rounds.
# [1000]	training's auc: 0.871625	valid_1's auc: 0.85424
# [2000]	training's auc: 0.900643	valid_1's auc: 0.877567
# [3000]	training's auc: 0.914337	valid_1's auc: 0.887402
# [4000]	training's auc: 0.92329	valid_1's auc: 0.892617
# [5000]	training's auc: 0.929679	valid_1's auc: 0.895791
# [6000]	training's auc: 0.935171	valid_1's auc: 0.897564
# Early stopping, best iteration is:
# [6583]	training's auc: 0.938111	valid_1's auc: 0.898087
# AUC = 0.8980872827198451
#
#
# Fold 4
# Training until validation scores don't improve for 250 rounds.
# [1000]	training's auc: 0.872005	valid_1's auc: 0.850176
# [2000]	training's auc: 0.901257	valid_1's auc: 0.873731
# [3000]	training's auc: 0.915197	valid_1's auc: 0.88262
# [4000]	training's auc: 0.924154	valid_1's auc: 0.887605
# [5000]	training's auc: 0.930666	valid_1's auc: 0.890185
# [6000]	training's auc: 0.935829	valid_1's auc: 0.891568
# [7000]	training's auc: 0.940814	valid_1's auc: 0.892343
# Early stopping, best iteration is:
# [6771]	training's auc: 0.939682	valid_1's auc: 0.892356
# AUC = 0.8923556129038968
# Overall AUC = 0.894004889525255
# Overall AUC = 0.894004889525255
#
#
# 6
#
#
# Fold 0
# Training until validation scores don't improve for 250 rounds.
# [1000]	training's auc: 0.872387	valid_1's auc: 0.847528
# [2000]	training's auc: 0.900764	valid_1's auc: 0.872178
# [3000]	training's auc: 0.91535	valid_1's auc: 0.883286
# [4000]	training's auc: 0.924381	valid_1's auc: 0.888921
# [5000]	training's auc: 0.931009	valid_1's auc: 0.891886
# [6000]	training's auc: 0.936437	valid_1's auc: 0.893679
# [7000]	training's auc: 0.9416	valid_1's auc: 0.894989
# Early stopping, best iteration is:
# [7155]	training's auc: 0.942391	valid_1's auc: 0.895185
# AUC = 0.8951850820524244
#
#
# Fold 1
# Training until validation scores don't improve for 250 rounds.
# [1000]	training's auc: 0.872548	valid_1's auc: 0.847383
# [2000]	training's auc: 0.901095	valid_1's auc: 0.870684
# [3000]	training's auc: 0.915472	valid_1's auc: 0.881513
# [4000]	training's auc: 0.924596	valid_1's auc: 0.887148
# [5000]	training's auc: 0.931276	valid_1's auc: 0.889855
# [6000]	training's auc: 0.93683	valid_1's auc: 0.891541
# [7000]	training's auc: 0.94182	valid_1's auc: 0.892107
# [8000]	training's auc: 0.946474	valid_1's auc: 0.892802
# Early stopping, best iteration is:
# [8260]	training's auc: 0.947722	valid_1's auc: 0.89288
# AUC = 0.8928802504888492
#
#
# Fold 2
# Training until validation scores don't improve for 250 rounds.
# [1000]	training's auc: 0.871587	valid_1's auc: 0.853877
# [2000]	training's auc: 0.900448	valid_1's auc: 0.877395
# [3000]	training's auc: 0.914827	valid_1's auc: 0.887828
# [4000]	training's auc: 0.923581	valid_1's auc: 0.892777
# [5000]	training's auc: 0.930086	valid_1's auc: 0.895771
# [6000]	training's auc: 0.935526	valid_1's auc: 0.897645
# [7000]	training's auc: 0.940649	valid_1's auc: 0.898846
# [8000]	training's auc: 0.94556	valid_1's auc: 0.899337
# Early stopping, best iteration is:
# [8103]	training's auc: 0.946044	valid_1's auc: 0.899407
# AUC = 0.8994073166505778
#
#
# Fold 3
# Training until validation scores don't improve for 250 rounds.
# [1000]	training's auc: 0.871874	valid_1's auc: 0.847598
# [2000]	training's auc: 0.901532	valid_1's auc: 0.87239
# [3000]	training's auc: 0.915991	valid_1's auc: 0.88206
# [4000]	training's auc: 0.924765	valid_1's auc: 0.886615
# [5000]	training's auc: 0.931323	valid_1's auc: 0.889236
# [6000]	training's auc: 0.936978	valid_1's auc: 0.890658
# [7000]	training's auc: 0.941944	valid_1's auc: 0.891425
# [8000]	training's auc: 0.946547	valid_1's auc: 0.891696
# [9000]	training's auc: 0.951043	valid_1's auc: 0.891976
# Early stopping, best iteration is:
# [8768]	training's auc: 0.95002	valid_1's auc: 0.892122
# AUC = 0.892122148582489
#
#
# Fold 4
# Training until validation scores don't improve for 250 rounds.
# [1000]	training's auc: 0.871092	valid_1's auc: 0.85534
# [2000]	training's auc: 0.900493	valid_1's auc: 0.878493
# [3000]	training's auc: 0.914458	valid_1's auc: 0.888491
# [4000]	training's auc: 0.923302	valid_1's auc: 0.894004
# [5000]	training's auc: 0.929809	valid_1's auc: 0.896908
# [6000]	training's auc: 0.935396	valid_1's auc: 0.898632
# [7000]	training's auc: 0.940534	valid_1's auc: 0.899687
# [8000]	training's auc: 0.945317	valid_1's auc: 0.900334
# Early stopping, best iteration is:
# [8710]	training's auc: 0.948596	valid_1's auc: 0.900604
# AUC = 0.9006041283995572
# Overall AUC = 0.8960172302696585
# Overall AUC = 0.8960172302696585
#
#
# 7
#
#
# Fold 0
# Training until validation scores don't improve for 250 rounds.
# [1000]	training's auc: 0.872929	valid_1's auc: 0.846226
# [2000]	training's auc: 0.901837	valid_1's auc: 0.872051
# [3000]	training's auc: 0.915257	valid_1's auc: 0.882948
# [4000]	training's auc: 0.923941	valid_1's auc: 0.888344
# [5000]	training's auc: 0.930163	valid_1's auc: 0.891545
# [6000]	training's auc: 0.935607	valid_1's auc: 0.893345
# [7000]	training's auc: 0.940775	valid_1's auc: 0.893936
# [8000]	training's auc: 0.945564	valid_1's auc: 0.894414
# [9000]	training's auc: 0.950099	valid_1's auc: 0.894879
# Early stopping, best iteration is:
# [9522]	training's auc: 0.952349	valid_1's auc: 0.895187
# AUC = 0.8951873097200563
#
#
# Fold 1
# Training until validation scores don't improve for 250 rounds.
# [1000]	training's auc: 0.872651	valid_1's auc: 0.851517
# [2000]	training's auc: 0.900977	valid_1's auc: 0.875716
# [3000]	training's auc: 0.915138	valid_1's auc: 0.885807
# [4000]	training's auc: 0.923851	valid_1's auc: 0.891023
# [5000]	training's auc: 0.930247	valid_1's auc: 0.893787
# [6000]	training's auc: 0.935859	valid_1's auc: 0.89483
# [7000]	training's auc: 0.940802	valid_1's auc: 0.895565
# Early stopping, best iteration is:
# [6988]	training's auc: 0.940747	valid_1's auc: 0.895585
# AUC = 0.8955845771144277
#
#
# Fold 2
# Training until validation scores don't improve for 250 rounds.
# [1000]	training's auc: 0.872542	valid_1's auc: 0.851701
# [2000]	training's auc: 0.901877	valid_1's auc: 0.874088
# [3000]	training's auc: 0.915437	valid_1's auc: 0.883891
# [4000]	training's auc: 0.924016	valid_1's auc: 0.889133
# [5000]	training's auc: 0.930481	valid_1's auc: 0.892155
# [6000]	training's auc: 0.935949	valid_1's auc: 0.894067
# [7000]	training's auc: 0.940979	valid_1's auc: 0.89496
# Early stopping, best iteration is:
# [7722]	training's auc: 0.944478	valid_1's auc: 0.895477
# AUC = 0.8954766589935893
#
#
# Fold 3
# Training until validation scores don't improve for 250 rounds.
# [1000]	training's auc: 0.873039	valid_1's auc: 0.847989
# [2000]	training's auc: 0.902497	valid_1's auc: 0.871169
# [3000]	training's auc: 0.916107	valid_1's auc: 0.8808
# [4000]	training's auc: 0.92439	valid_1's auc: 0.886143
# [5000]	training's auc: 0.930895	valid_1's auc: 0.888619
# [6000]	training's auc: 0.936332	valid_1's auc: 0.889871
# [7000]	training's auc: 0.941321	valid_1's auc: 0.890496
# Early stopping, best iteration is:
# [7296]	training's auc: 0.942684	valid_1's auc: 0.890814
# AUC = 0.8908141045138851
#
#
# Fold 4
# Training until validation scores don't improve for 250 rounds.
# [1000]	training's auc: 0.871854	valid_1's auc: 0.853587
# [2000]	training's auc: 0.900571	valid_1's auc: 0.876713
# [3000]	training's auc: 0.914674	valid_1's auc: 0.886845
# [4000]	training's auc: 0.923125	valid_1's auc: 0.891713
# [5000]	training's auc: 0.929695	valid_1's auc: 0.894934
# [6000]	training's auc: 0.935127	valid_1's auc: 0.896179
# [7000]	training's auc: 0.940054	valid_1's auc: 0.896952
# Early stopping, best iteration is:
# [7240]	training's auc: 0.941283	valid_1's auc: 0.897054
# AUC = 0.8970537496035409
# Overall AUC = 0.8947369353992684
# Overall AUC = 0.8947369353992684
#
#
# 8
#
#
# Fold 0
# Training until validation scores don't improve for 250 rounds.
# [1000]	training's auc: 0.873736	valid_1's auc: 0.843527
# [2000]	training's auc: 0.902196	valid_1's auc: 0.86696
# [3000]	training's auc: 0.916298	valid_1's auc: 0.877723
# [4000]	training's auc: 0.925122	valid_1's auc: 0.883442
# [5000]	training's auc: 0.931366	valid_1's auc: 0.886587
# [6000]	training's auc: 0.936565	valid_1's auc: 0.888652
# [7000]	training's auc: 0.941591	valid_1's auc: 0.889726
# [8000]	training's auc: 0.946313	valid_1's auc: 0.890094
# [9000]	training's auc: 0.950867	valid_1's auc: 0.890447
# Early stopping, best iteration is:
# [8757]	training's auc: 0.949811	valid_1's auc: 0.890545
# AUC = 0.8905454691715551
#
#
# Fold 1
# Training until validation scores don't improve for 250 rounds.
# [1000]	training's auc: 0.874267	valid_1's auc: 0.849641
# [2000]	training's auc: 0.902519	valid_1's auc: 0.871621
# [3000]	training's auc: 0.916597	valid_1's auc: 0.88109
# [4000]	training's auc: 0.925257	valid_1's auc: 0.886351
# [5000]	training's auc: 0.931687	valid_1's auc: 0.889107
# [6000]	training's auc: 0.937049	valid_1's auc: 0.890852
# [7000]	training's auc: 0.941954	valid_1's auc: 0.891884
# [8000]	training's auc: 0.946619	valid_1's auc: 0.892363
# Early stopping, best iteration is:
# [8255]	training's auc: 0.94783	valid_1's auc: 0.892565
# AUC = 0.8925647261206405
#
#
# Fold 2
# Training until validation scores don't improve for 250 rounds.
# [1000]	training's auc: 0.869997	valid_1's auc: 0.857964
# [2000]	training's auc: 0.899375	valid_1's auc: 0.883846
# [3000]	training's auc: 0.913668	valid_1's auc: 0.89437
# [4000]	training's auc: 0.922783	valid_1's auc: 0.899811
# [5000]	training's auc: 0.929173	valid_1's auc: 0.902639
# [6000]	training's auc: 0.934665	valid_1's auc: 0.904206
# [7000]	training's auc: 0.939898	valid_1's auc: 0.90484
# Early stopping, best iteration is:
# [7340]	training's auc: 0.941592	valid_1's auc: 0.905101
# AUC = 0.9051013588772555
#
#
# Fold 3
# Training until validation scores don't improve for 250 rounds.
# [1000]	training's auc: 0.872292	valid_1's auc: 0.850528
# [2000]	training's auc: 0.901105	valid_1's auc: 0.874397
# [3000]	training's auc: 0.915325	valid_1's auc: 0.88445
# [4000]	training's auc: 0.924303	valid_1's auc: 0.889847
# [5000]	training's auc: 0.930789	valid_1's auc: 0.892731
# [6000]	training's auc: 0.936104	valid_1's auc: 0.894286
# [7000]	training's auc: 0.941131	valid_1's auc: 0.89535
# [8000]	training's auc: 0.945976	valid_1's auc: 0.895574
# [9000]	training's auc: 0.950481	valid_1's auc: 0.89574
# Early stopping, best iteration is:
# [8836]	training's auc: 0.949716	valid_1's auc: 0.895793
# AUC = 0.8957933146739354
#
#
# Fold 4
# Training until validation scores don't improve for 250 rounds.
# [1000]	training's auc: 0.87312	valid_1's auc: 0.849275
# [2000]	training's auc: 0.901623	valid_1's auc: 0.873351
# [3000]	training's auc: 0.915988	valid_1's auc: 0.883849
# [4000]	training's auc: 0.924593	valid_1's auc: 0.888902
# [5000]	training's auc: 0.931109	valid_1's auc: 0.892001
# [6000]	training's auc: 0.936604	valid_1's auc: 0.893702
# [7000]	training's auc: 0.941498	valid_1's auc: 0.894398
# [8000]	training's auc: 0.946232	valid_1's auc: 0.895073
# [9000]	training's auc: 0.950786	valid_1's auc: 0.895463
# Early stopping, best iteration is:
# [9106]	training's auc: 0.951236	valid_1's auc: 0.895491
# AUC = 0.895490696375595
# Overall AUC = 0.8957607573620675
# Overall AUC = 0.8957607573620675
#
#
# 9
#
#
# Fold 0
# Training until validation scores don't improve for 250 rounds.
# [1000]	training's auc: 0.872032	valid_1's auc: 0.849592
# [2000]	training's auc: 0.902146	valid_1's auc: 0.876057
# [3000]	training's auc: 0.916413	valid_1's auc: 0.887334
# [4000]	training's auc: 0.925258	valid_1's auc: 0.893025
# [5000]	training's auc: 0.931597	valid_1's auc: 0.896671
# [6000]	training's auc: 0.937095	valid_1's auc: 0.898714
# [7000]	training's auc: 0.942115	valid_1's auc: 0.89985
# Early stopping, best iteration is:
# [7595]	training's auc: 0.944952	valid_1's auc: 0.900274
# AUC = 0.9002742506373604
#
#
# Fold 1
# Training until validation scores don't improve for 250 rounds.
# [1000]	training's auc: 0.872454	valid_1's auc: 0.853222
# [2000]	training's auc: 0.901713	valid_1's auc: 0.877955
# [3000]	training's auc: 0.916339	valid_1's auc: 0.889102
# [4000]	training's auc: 0.925317	valid_1's auc: 0.894401
# [5000]	training's auc: 0.931983	valid_1's auc: 0.897084
# [6000]	training's auc: 0.937431	valid_1's auc: 0.898779
# [7000]	training's auc: 0.942362	valid_1's auc: 0.899479
# [8000]	training's auc: 0.947135	valid_1's auc: 0.899973
# Early stopping, best iteration is:
# [8000]	training's auc: 0.947135	valid_1's auc: 0.899973
# AUC = 0.8999729585901339
#
#
# Fold 2
# Training until validation scores don't improve for 250 rounds.
# [1000]	training's auc: 0.872827	valid_1's auc: 0.858507
# [2000]	training's auc: 0.902935	valid_1's auc: 0.881469
# [3000]	training's auc: 0.917035	valid_1's auc: 0.890397
# [4000]	training's auc: 0.925647	valid_1's auc: 0.89473
# [5000]	training's auc: 0.93202	valid_1's auc: 0.897534
# [6000]	training's auc: 0.937495	valid_1's auc: 0.899238
# [7000]	training's auc: 0.942287	valid_1's auc: 0.900221
# Early stopping, best iteration is:
# [7450]	training's auc: 0.94441	valid_1's auc: 0.900657
# AUC = 0.9006569763124675
#
#
# Fold 3
# Training until validation scores don't improve for 250 rounds.
# [1000]	training's auc: 0.872905	valid_1's auc: 0.849823
# [2000]	training's auc: 0.902352	valid_1's auc: 0.87622
# [3000]	training's auc: 0.91681	valid_1's auc: 0.886928
# [4000]	training's auc: 0.92588	valid_1's auc: 0.892791
# [5000]	training's auc: 0.932233	valid_1's auc: 0.895534
# [6000]	training's auc: 0.937699	valid_1's auc: 0.897391
# [7000]	training's auc: 0.942679	valid_1's auc: 0.898262
# [8000]	training's auc: 0.947373	valid_1's auc: 0.898589
# Early stopping, best iteration is:
# [8565]	training's auc: 0.949881	valid_1's auc: 0.89884
# AUC = 0.8988402995698277
#
#
# Fold 4
# Training until validation scores don't improve for 250 rounds.
# [1000]	training's auc: 0.874841	valid_1's auc: 0.847371
# [2000]	training's auc: 0.904445	valid_1's auc: 0.870741
# [3000]	training's auc: 0.91876	valid_1's auc: 0.880959
# [4000]	training's auc: 0.927472	valid_1's auc: 0.886206
# [5000]	training's auc: 0.933771	valid_1's auc: 0.888695
# [6000]	training's auc: 0.939041	valid_1's auc: 0.890316
# [7000]	training's auc: 0.943886	valid_1's auc: 0.891267
# [8000]	training's auc: 0.948473	valid_1's auc: 0.891719
# Early stopping, best iteration is:
# [8230]	training's auc: 0.94952	valid_1's auc: 0.891907
# AUC = 0.8919070097554159
# Overall AUC = 0.8982933620284984
# Overall AUC = 0.8982933620284984
#
#
# 10
#
#
# Fold 0
# Training until validation scores don't improve for 250 rounds.
# [1000]	training's auc: 0.87059	valid_1's auc: 0.852343
# [2000]	training's auc: 0.901244	valid_1's auc: 0.87573
# [3000]	training's auc: 0.915608	valid_1's auc: 0.884807
# [4000]	training's auc: 0.924404	valid_1's auc: 0.888995
# [5000]	training's auc: 0.930799	valid_1's auc: 0.891113
# [6000]	training's auc: 0.936326	valid_1's auc: 0.892081
# [7000]	training's auc: 0.941283	valid_1's auc: 0.892464
# Early stopping, best iteration is:
# [6928]	training's auc: 0.940949	valid_1's auc: 0.892499
# AUC = 0.8924991336848097
#
#
# Fold 1
# Training until validation scores don't improve for 250 rounds.
# [1000]	training's auc: 0.870406	valid_1's auc: 0.847562
# [2000]	training's auc: 0.900498	valid_1's auc: 0.874081
# [3000]	training's auc: 0.91478	valid_1's auc: 0.884723
# [4000]	training's auc: 0.923295	valid_1's auc: 0.890099
# [5000]	training's auc: 0.929688	valid_1's auc: 0.89332
# [6000]	training's auc: 0.935104	valid_1's auc: 0.894917
# [7000]	training's auc: 0.940077	valid_1's auc: 0.89585
# Early stopping, best iteration is:
# [7745]	training's auc: 0.943652	valid_1's auc: 0.896432
# AUC = 0.8964321427687434
#
#
# Fold 2
# Training until validation scores don't improve for 250 rounds.
# [1000]	training's auc: 0.870655	valid_1's auc: 0.854281
# [2000]	training's auc: 0.900267	valid_1's auc: 0.878077
# [3000]	training's auc: 0.914554	valid_1's auc: 0.887442
# [4000]	training's auc: 0.923518	valid_1's auc: 0.892317
# [5000]	training's auc: 0.929942	valid_1's auc: 0.894746
# [6000]	training's auc: 0.935582	valid_1's auc: 0.896133
# [7000]	training's auc: 0.940712	valid_1's auc: 0.896715
# [8000]	training's auc: 0.945413	valid_1's auc: 0.896949
# Early stopping, best iteration is:
# [8168]	training's auc: 0.946211	valid_1's auc: 0.897102
# AUC = 0.897102485087003
#
#
# Fold 3
# Training until validation scores don't improve for 250 rounds.
# [1000]	training's auc: 0.86961	valid_1's auc: 0.850138
# [2000]	training's auc: 0.899649	valid_1's auc: 0.875947
# [3000]	training's auc: 0.914002	valid_1's auc: 0.886949
# [4000]	training's auc: 0.922682	valid_1's auc: 0.892168
# [5000]	training's auc: 0.929278	valid_1's auc: 0.895058
# [6000]	training's auc: 0.934787	valid_1's auc: 0.89675
# [7000]	training's auc: 0.939924	valid_1's auc: 0.897748
# Early stopping, best iteration is:
# [7511]	training's auc: 0.942458	valid_1's auc: 0.897911
# AUC = 0.897911333210049
#
#
# Fold 4
# Training until validation scores don't improve for 250 rounds.
# [1000]	training's auc: 0.871904	valid_1's auc: 0.842242
# [2000]	training's auc: 0.901544	valid_1's auc: 0.867191
# [3000]	training's auc: 0.915897	valid_1's auc: 0.878624
# [4000]	training's auc: 0.924554	valid_1's auc: 0.884402
# [5000]	training's auc: 0.930809	valid_1's auc: 0.887634
# [6000]	training's auc: 0.936228	valid_1's auc: 0.88916
# [7000]	training's auc: 0.941213	valid_1's auc: 0.890268
# [8000]	training's auc: 0.946123	valid_1's auc: 0.890844
# Early stopping, best iteration is:
# [7906]	training's auc: 0.945667	valid_1's auc: 0.890872
# AUC = 0.8908721146091274
# Overall AUC = 0.8949392676848712
# Overall AUC = 0.8949392676848712
#
#
# 11
#
#
# Fold 0
# Training until validation scores don't improve for 250 rounds.
# [1000]	training's auc: 0.872602	valid_1's auc: 0.851767
# [2000]	training's auc: 0.90192	valid_1's auc: 0.874752
# [3000]	training's auc: 0.916064	valid_1's auc: 0.884133
# [4000]	training's auc: 0.92457	valid_1's auc: 0.888967
# [5000]	training's auc: 0.930908	valid_1's auc: 0.891691
# [6000]	training's auc: 0.936227	valid_1's auc: 0.893311
# [7000]	training's auc: 0.941152	valid_1's auc: 0.893938
# Early stopping, best iteration is:
# [7748]	training's auc: 0.944607	valid_1's auc: 0.894172
# AUC = 0.8941724833543725
#
#
# Fold 1
# Training until validation scores don't improve for 250 rounds.
# [1000]	training's auc: 0.872525	valid_1's auc: 0.846811
# [2000]	training's auc: 0.901711	valid_1's auc: 0.872447
# [3000]	training's auc: 0.915493	valid_1's auc: 0.883417
# [4000]	training's auc: 0.924152	valid_1's auc: 0.889439
# [5000]	training's auc: 0.930466	valid_1's auc: 0.892616
# [6000]	training's auc: 0.935889	valid_1's auc: 0.894513
# [7000]	training's auc: 0.940947	valid_1's auc: 0.895342
# [8000]	training's auc: 0.945683	valid_1's auc: 0.89593
# [9000]	training's auc: 0.950293	valid_1's auc: 0.896053
# Early stopping, best iteration is:
# [8846]	training's auc: 0.949598	valid_1's auc: 0.89612
# AUC = 0.8961202074206084
#
#
# Fold 2
# Training until validation scores don't improve for 250 rounds.
# [1000]	training's auc: 0.871754	valid_1's auc: 0.850758
# [2000]	training's auc: 0.900759	valid_1's auc: 0.875251
# [3000]	training's auc: 0.915249	valid_1's auc: 0.885514
# [4000]	training's auc: 0.923992	valid_1's auc: 0.890929
# [5000]	training's auc: 0.930352	valid_1's auc: 0.893593
# [6000]	training's auc: 0.935758	valid_1's auc: 0.895039
# [7000]	training's auc: 0.940738	valid_1's auc: 0.895812
# [8000]	training's auc: 0.94551	valid_1's auc: 0.896464
# Early stopping, best iteration is:
# [8252]	training's auc: 0.946688	valid_1's auc: 0.896547
# AUC = 0.8965470532907602
#
#
# Fold 3
# Training until validation scores don't improve for 250 rounds.
# [1000]	training's auc: 0.87266	valid_1's auc: 0.853443
# [2000]	training's auc: 0.901474	valid_1's auc: 0.876612
# [3000]	training's auc: 0.91523	valid_1's auc: 0.88739
# [4000]	training's auc: 0.924011	valid_1's auc: 0.892574
# [5000]	training's auc: 0.930286	valid_1's auc: 0.894865
# [6000]	training's auc: 0.935597	valid_1's auc: 0.896447
# [7000]	training's auc: 0.940598	valid_1's auc: 0.896871
# Early stopping, best iteration is:
# [7699]	training's auc: 0.944019	valid_1's auc: 0.897283
# AUC = 0.8972833754768111
#
#
# Fold 4
# Training until validation scores don't improve for 250 rounds.
# [1000]	training's auc: 0.871652	valid_1's auc: 0.851103
# [2000]	training's auc: 0.901838	valid_1's auc: 0.876892
# [3000]	training's auc: 0.915995	valid_1's auc: 0.886445
# [4000]	training's auc: 0.924708	valid_1's auc: 0.890917
# [5000]	training's auc: 0.931111	valid_1's auc: 0.893247
# [6000]	training's auc: 0.936398	valid_1's auc: 0.894604
# [7000]	training's auc: 0.941429	valid_1's auc: 0.895282
# [8000]	training's auc: 0.946146	valid_1's auc: 0.895568
# Early stopping, best iteration is:
# [8254]	training's auc: 0.947259	valid_1's auc: 0.895709
# AUC = 0.8957086211730905
# Overall AUC = 0.8959547292800061
# Overall AUC = 0.8959547292800061
#
#
# 12
#
#
# Fold 0
# Training until validation scores don't improve for 250 rounds.
# [1000]	training's auc: 0.871004	valid_1's auc: 0.854177
# [2000]	training's auc: 0.899815	valid_1's auc: 0.879227
# [3000]	training's auc: 0.914294	valid_1's auc: 0.890356
# [4000]	training's auc: 0.922933	valid_1's auc: 0.896422
# [5000]	training's auc: 0.929568	valid_1's auc: 0.89929
# [6000]	training's auc: 0.934999	valid_1's auc: 0.900896
# [7000]	training's auc: 0.940213	valid_1's auc: 0.901622
# [8000]	training's auc: 0.945083	valid_1's auc: 0.902321
# Early stopping, best iteration is:
# [8365]	training's auc: 0.946779	valid_1's auc: 0.902435
# AUC = 0.9024350263607336
#
#
# Fold 1
# Training until validation scores don't improve for 250 rounds.
# [1000]	training's auc: 0.873404	valid_1's auc: 0.847664
# [2000]	training's auc: 0.902273	valid_1's auc: 0.871733
# [3000]	training's auc: 0.916634	valid_1's auc: 0.881896
# [4000]	training's auc: 0.925139	valid_1's auc: 0.88696
# [5000]	training's auc: 0.931474	valid_1's auc: 0.88985
# [6000]	training's auc: 0.936799	valid_1's auc: 0.891445
# [7000]	training's auc: 0.941702	valid_1's auc: 0.892356
# Early stopping, best iteration is:
# [7472]	training's auc: 0.944022	valid_1's auc: 0.892781
# AUC = 0.8927814286775079
#
#
# Fold 2
# Training until validation scores don't improve for 250 rounds.
# [1000]	training's auc: 0.873174	valid_1's auc: 0.852486
# [2000]	training's auc: 0.901671	valid_1's auc: 0.875679
# [3000]	training's auc: 0.916034	valid_1's auc: 0.88502
# [4000]	training's auc: 0.924808	valid_1's auc: 0.889823
# [5000]	training's auc: 0.931246	valid_1's auc: 0.893202
# [6000]	training's auc: 0.936668	valid_1's auc: 0.894668
# [7000]	training's auc: 0.941472	valid_1's auc: 0.895392
# [8000]	training's auc: 0.946201	valid_1's auc: 0.89584
# Early stopping, best iteration is:
# [8060]	training's auc: 0.946451	valid_1's auc: 0.895945
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-10-7c25776399d0> in <module>()
#      10     y_train=new_train_df[train_label]
#      11
# ---> 12     oof_preds,test_preds=LGBM(x_train,y_train,x_test,i)
#      13
#      14     roc_score = roc_auc_score(y_train, oof_preds.ravel())
#
# <ipython-input-6-af4e1396884e> in LGBM(x_train, y_train, x_test, seed)
#      38         clf = lgb.train(param, trn_data, num_round, valid_sets = [trn_data, val_data], verbose_eval=1000, early_stopping_rounds = 250)
#      39         val_pred = clf.predict(val_x, num_iteration=clf.best_iteration)
# ---> 40         test_pred = clf.predict(x_test, num_iteration=clf.best_iteration)
#      41
#      42         print("AUC = {}".format(roc_auc_score(val_y, val_pred)))
#
# C:\Users\tatsuya.okamoto\AppData\Local\Continuum\Anaconda3\lib\site-packages\lightgbm\basic.py in predict(self, data, num_iteration, raw_score, pred_leaf, pred_contrib, data_has_header, is_reshape, **kwargs)
#    2201         return predictor.predict(data, num_iteration,
#    2202                                  raw_score, pred_leaf, pred_contrib,
# -> 2203                                  data_has_header, is_reshape)
#    2204
#    2205     def refit(self, data, label, decay_rate=0.9, **kwargs):
#
# C:\Users\tatsuya.okamoto\AppData\Local\Continuum\Anaconda3\lib\site-packages\lightgbm\basic.py in predict(self, data, num_iteration, raw_score, pred_leaf, pred_contrib, data_has_header, is_reshape)
#     434         if isinstance(data, Dataset):
#     435             raise TypeError("Cannot use Dataset instance for prediction, please use raw data instead")
# --> 436         data = _data_from_pandas(data, None, None, self.pandas_categorical)[0]
#     437         predict_type = C_API_PREDICT_NORMAL
#     438         if raw_score:
#
# C:\Users\tatsuya.okamoto\AppData\Local\Continuum\Anaconda3\lib\site-packages\lightgbm\basic.py in _data_from_pandas(data, feature_name, categorical_feature, pandas_categorical)
#     246             raise ValueError('Input data must be 2 dimensional and non empty.')
#     247         if feature_name == 'auto' or feature_name is None:
# --> 248             data = data.rename(columns=str)
#     249         cat_cols = data.select_dtypes(include=['category']).columns
#     250         if pandas_categorical is None:  # train dataset
#
# C:\Users\tatsuya.okamoto\AppData\Local\Continuum\Anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     185         @wraps(func)
#     186         def wrapper(*args, **kwargs):
# --> 187             return func(*args, **kwargs)
#     188
#     189         if not PY2:
#
# C:\Users\tatsuya.okamoto\AppData\Local\Continuum\Anaconda3\lib\site-packages\pandas\core\frame.py in rename(self, *args, **kwargs)
#    3779         kwargs.pop('axis', None)
#    3780         kwargs.pop('mapper', None)
# -> 3781         return super(DataFrame, self).rename(**kwargs)
#    3782
#    3783     @Substitution(**_shared_doc_kwargs)
#
# C:\Users\tatsuya.okamoto\AppData\Local\Continuum\Anaconda3\lib\site-packages\pandas\core\generic.py in rename(self, *args, **kwargs)
#     959
#     960         self._consolidate_inplace()
# --> 961         result = self if inplace else self.copy(deep=copy)
#     962
#     963         # start in the axis order to eliminate too many copies
#
# C:\Users\tatsuya.okamoto\AppData\Local\Continuum\Anaconda3\lib\site-packages\pandas\core\generic.py in copy(self, deep)
#    5112         dtype: object
#    5113         """
# -> 5114         data = self._data.copy(deep=deep)
#    5115         return self._constructor(data).__finalize__(self)
#    5116
#
# C:\Users\tatsuya.okamoto\AppData\Local\Continuum\Anaconda3\lib\site-packages\pandas\core\internals.py in copy(self, deep, mgr)
#    3918             new_axes = list(self.axes)
#    3919         return self.apply('copy', axes=new_axes, deep=deep,
# -> 3920                           do_integrity_check=False)
#    3921
#    3922     def as_array(self, transpose=False, items=None):
#
# C:\Users\tatsuya.okamoto\AppData\Local\Continuum\Anaconda3\lib\site-packages\pandas\core\internals.py in apply(self, f, axes, filter, do_integrity_check, consolidate, **kwargs)
#    3579
#    3580             kwargs['mgr'] = self
# -> 3581             applied = getattr(b, f)(**kwargs)
#    3582             result_blocks = _extend_blocks(applied, result_blocks)
#    3583
#
# C:\Users\tatsuya.okamoto\AppData\Local\Continuum\Anaconda3\lib\site-packages\pandas\core\internals.py in copy(self, deep, mgr)
#     776         values = self.values
#     777         if deep:
# --> 778             values = values.copy()
#     779         return self.make_block_same_class(values)
#     780
#
# MemoryError:

# %%
all_test_preds

# %%
#結果保存
if submit_flg ==1:
    series_oof_preds = pd.Series(data=all_oof_preds[:,0], name=save_col_name, dtype='float')
    series_test_preds = pd.Series(data=all_test_preds[:,0], name=save_col_name, dtype='float')

    series_oof_preds.to_csv(oof_preds_dir,header=True, index=False)
    series_test_preds.to_csv(test_preds_dir,header=True, index=False)

    sample = pd.read_csv(sample_submission_dir)
    sample.target = all_test_preds[:,0].astype(float)
    sample.ID_code = test_df['ID_code']
    sample.to_csv(submission_dir, index=False)
